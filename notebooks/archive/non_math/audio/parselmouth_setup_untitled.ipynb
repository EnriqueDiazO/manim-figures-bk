# %%
# !pip install praat-parselmouth
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 37.4 MB/s eta 0:00:00
# ...

# %%
# Please add breath.wav by dragging the file into Files zone
