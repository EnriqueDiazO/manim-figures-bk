# %%
import sys
# Obtener argumentos de línea de comandos
argumentos = sys.argv
print("Argumentos:", argumentos)
# Out:
# Argumentos: ['/usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-0a073c77-84fa-4661-8dea-3fc5b161b01a.json']
