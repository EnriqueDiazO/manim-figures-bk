# %%
/home/enrique/0 Colegio cientifico de datos/Diplomados/Python Diplomado Agosto/Notas sesion 7/test/test 1/test 11/test.txt

# %%
import sys
argumentos = sys.argv
print(argumentos)
# Out:
# ['/usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-8e81a17c-2270-48b5-9253-fa65355ad4ff.json']
