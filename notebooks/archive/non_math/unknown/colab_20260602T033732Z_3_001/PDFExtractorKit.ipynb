# %%
# !nvidia-smi
# Out:
# Thu Apr 17 18:09:34 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !git clone https://github.com/opendatalab/PDF-Extract-Kit.git /content/PDF-Extract-Kit
# Out:
# Cloning into '/content/PDF-Extract-Kit'...
# remote: Enumerating objects: 1464, done.
# remote: Counting objects: 100% (265/265), done.
# remote: Compressing objects: 100% (130/130), done.
# remote: Total 1464 (delta 183), reused 135 (delta 135), pack-reused 1199 (from 3)
# Receiving objects: 100% (1464/1464), 51.30 MiB | 16.40 MiB/s, done.
# Resolving deltas: 100% (707/707), done.

# %%
# !git clone --branch PDF-Extract-Kit-0.1.0-released --depth 1 https://github.com/opendatalab/PDF-Extract-Kit.git /content/PDF-Extract-Kit
# Out:
# Cloning into '/content/PDF-Extract-Kit'...
# remote: Enumerating objects: 105, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 105 (delta 9), reused 63 (delta 6), pack-reused 0 (from 0)
# Receiving objects: 100% (105/105), 16.49 MiB | 35.03 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# Note: switching to '2794fa367c6a3e321ef247b9925274d1a3b4cab3'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false

# %%
# !pip install numpy==1.24.4 opencv-python-headless==4.7.0.72 transformers==4.36.2 torch torchvision
# !pip install transformers==4.40.0 --force-reinstall

import os
os.kill(os.getpid(), 9)  # Reinicia el entorno de ejecución (necesario)
# Out:
# ...
#   Using cached transformers-4.40.0-py3-none-any.whl.metadata (137 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.5 MB/s eta 0:00:00
# ...
#   Using cached tokenizers-0.19.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.1 MB/s eta 0:00:00
# ...
# Using cached transformers-4.40.0-py3-none-any.whl (9.0 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 481.4/481.4 kB 21.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 110.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.0/763.0 kB 52.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 792.7/792.7 kB 57.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 39.2 MB/s eta 0:00:00
# ...

# %%
# %cd /content/PDF-Extract-Kit/
# Out:
# /content/PDF-Extract-Kit

# %%
# %cd /content/PDF-Extract-Kit

import sys
sys.modules.pop("PIL",None)
sys.modules.pop("pydevd_plugins",None)
# !pip install -r requirements.txt
# !pip install --extra-index-url https://miropsota.github.io/torch_packages_builder detectron2=0.6+pt2.3.1cu121
# !pip install pillow==8.4.0
# Out:
# /content/PDF-Extract-Kit
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 17.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.6/137.6 kB 13.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 8.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 11.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.0/780.0 kB 60.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 120.6 MB/s eta 0:00:00
# ...

# %%
# !git lfs install
# Out:
# Updated git hooks.
# Git LFS initialized.

# %%
# !rm -rf /content/HF-PDF-Extract-Kit && git clone https://huggingface.co/wanderkid/PDF-Extract-Kit /content/HF-PDF-Extract-Kit
# !rm -rf models/ && mv /content/HF-PDF-Extract-Kit/models /content/PDF-Extract-Kit/models
# Out:
# Cloning into '/content/HF-PDF-Extract-Kit'...
# remote: Enumerating objects: 94, done.
# remote: Counting objects: 100% (90/90), done.
# remote: Compressing objects: 100% (87/87), done.
# remote: Total 94 (delta 28), reused 0 (delta 0), pack-reused 4 (from 1)
# Unpacking objects: 100% (94/94), 1.42 MiB | 6.69 MiB/s, done.
# Filtering content: 100% (14/14), 8.17 GiB | 39.20 MiB/s, done.

# %%
# !wget https://arxiv.org/pdf/1706.03762 -O 1706.03762.pdf
# Out:
# --2025-04-17 18:24:26--  https://arxiv.org/pdf/1706.03762
# Resolving arxiv.org (arxiv.org)... 151.101.67.42, 151.101.131.42, 151.101.195.42, ...
# Connecting to arxiv.org (arxiv.org)|151.101.67.42|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2215244 (2.1M) [application/pdf]
# Saving to: ‘1706.03762.pdf’
#
# 1706.03762.pdf      100%[===================>]   2.11M  --.-KB/s    in 0.05s
#
# 2025-04-17 18:24:26 (43.0 MB/s) - ‘1706.03762.pdf’ saved [2215244/2215244]

# %%
# !python pdf_extract.py --pdf 1706.03762.pdf
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/content/PDF-Extract-Kit/pdf_extract.py", line 2, in <module>
#     import cv2
#   File "/usr/local/lib/python3.11/dist-packages/cv2/__init__.py", line 181, in <module>
#     bootstrap()
#   File "/usr/local/lib/python3.11/dist-packages/cv2/__init__.py", line 153, in bootstrap
#     native_module = importlib.import_module("cv2")
#   File "/usr/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
# ...

# %%
# !git clone --branch PDF-Extract-Kit-0.1.1-released --depth 1 https://github.com/opendatalab/PDF-Extract-Kit.git /content/PDF-Extract-Kit
# Out:
# fatal: destination path '/content/PDF-Extract-Kit' already exists and is not an empty directory.

# %%
# %cd /content/PDF-Extract-Kit
# Out:
# /content/PDF-Extract-Kit

# %%
#import sys
#import sys
#sys.path.append("/content/PDF-Extract-Kit/project/pdf2markdown/scripts")

# !python /content/PDF-Extract-Kit/pdf_extract.py --pdf 1706.03762.pdf --output output --vis --render
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744910774.355755    4848 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744910774.362130    4848 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Traceback (most recent call last):
#   File "/content/PDF-Extract-Kit/pdf_extract.py", line 22, in <module>
#     from struct_eqtable import build_model
# ModuleNotFoundError: No module named 'struct_eqtable'

# %%
# !pip install struct-eqtable

# %%
# !git clone https://github.com/facebookresearch/detectron2.git
# !python -m pip install -e detectron2
# Out:
# Cloning into 'detectron2'...
# remote: Enumerating objects: 15842, done.
# remote: Counting objects: 100% (69/69), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 15842 (delta 38), reused 15 (delta 14), pack-reused 15773 (from 2)
# Receiving objects: 100% (15842/15842), 6.41 MiB | 19.26 MiB/s, done.
# Resolving deltas: 100% (11537/11537), done.
# Obtaining file:///content/PDF-Extract-Kit/detectron2
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 16.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 86.1 MB/s eta 0:00:00
# ...

# %%
# !pip install \
  paddleocr \
  opencv-python-headless \
  PyMuPDF \
  pyyaml \
  pytz \
  Pillow \
  torchvision \
  torch \
  ultralytics \
  unimernet \
  matplotlib \
  numpy \
  pandas \
  einops \
  tqdm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.2/87.2 kB 6.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.3/266.3 kB 12.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 9.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 67.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 75.0 MB/s eta 0:00:00
# ...

# %%
# !ls -lh /content/PDF-Extract-Kit/models/MFR/unimernet_small/
# Out:
# total 775M
# -rw-r--r-- 1 root root 4.9K Apr 17 17:17 config.json
# -rw-r--r-- 1 root root  617 Apr 17 17:17 preprocessor_config.json
# -rw-r--r-- 1 root root 773M Apr 17 17:18 pytorch_model.pth
# -rw-r--r-- 1 root root 1.1K Apr 17 17:17 README.md
# -rw-r--r-- 1 root root 4.4K Apr 17 17:17 tokenizer_config.json
# -rw-r--r-- 1 root root 2.1M Apr 17 17:17 tokenizer.json
# -rw-r--r-- 1 root root  833 Apr 17 17:17 unimernet_small.yaml
