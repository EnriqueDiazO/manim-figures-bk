# %%
import numpy as np
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Load sample dataset (Iris dataset)
iris = load_iris()
X = iris.data
y = iris.target

# Initialize t-SNE
tsne = TSNE(n_components=2, random_state=42)

# Fit and transform the data
X_tsne = tsne.fit_transform(X)

# Plot the t-SNE results
plt.figure(figsize=(8, 6))
scatter = plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y, cmap='viridis', edgecolor='k')
plt.colorbar(scatter)
plt.title('t-SNE Visualization of Iris Dataset')
plt.xlabel('t-SNE Component 1')
plt.ylabel('t-SNE Component 2')
plt.show()

# %%
import numpy as np
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# Cargar el dataset de Iris
iris = load_iris()
X = iris.data

# Aplicar k-means para clustering (3 clusters en este caso)
kmeans = KMeans(n_clusters=3, random_state=42)
y_kmeans = kmeans.fit_predict(X)

# Aplicar t-SNE para la reducción de dimensionalidad
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X)

# Visualizar los resultados
plt.figure(figsize=(8, 6))
scatter = plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y_kmeans, cmap='viridis', edgecolor='k')
plt.colorbar(scatter)
plt.title('Visualización de Clusters con t-SNE')
plt.xlabel('t-SNE Componente 1')
plt.ylabel('t-SNE Componente 2')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
from IPython.display import IFrame

# Reemplaza 'TU_ID_DE_VIDEO' por el ID real del video en Google Drive.
video_id = '1vX2e90UKJFPEObkczCvIMJiPukdurZsh'
IFrame(f'https://drive.google.com/file/d/{video_id}/preview', width=1280, height=800)
# Out:
#         <iframe
#             width="1280"
#             height="800"
#             src="https://drive.google.com/file/d/1vX2e90UKJFPEObkczCvIMJiPukdurZsh/preview"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
