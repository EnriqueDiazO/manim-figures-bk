# %%
| **Variable** | **Definición** | **Fórmula** |
|--------------|----------------|-------------|
| **`f0_p`**   | Frecuencia fundamental (F0) en el período de análisis. Calculada usando el comando `Get quantile...` de Praat para obtener el percentil 50 (mediana) de la frecuencia fundamental en Hertz. | `f0_p = pm.praat.call(pitch, "Get quantile...", xmin, xmax, 0.5, "Hertz")` |
| **`f1_p`**   | Frecuencia del primer formante (F1) en el período de análisis. Calculada usando el comando `Get quantile...` de Praat para obtener el percentil 50 (mediana) de F1 en Hertz. | `f1_p = pm.praat.call(formant, "Get quantile...", 1, xmin, xmax, "Hertz", 0.5)` |
| **`stdevF1`**| Desviación estándar de la frecuencia del primer formante (F1). Calculada usando el comando `Get standard deviation` de Praat para el primer formante en Hertz. | `stdevF1 = pm.praat.call(formant, "Get standard deviation", 1, xmin, xmax, "Hertz")` |
| **`f2_p`**   | Frecuencia del segundo formante (F2) en el período de análisis. Calculada usando el comando `Get quantile...` de Praat para obtener el percentil 50 (mediana) de F2 en Hertz. | `f2_p = pm.praat.call(formant, "Get quantile...", 2, xmin, xmax, "Hertz", 0.5)` |
| **`stdevF2`**| Desviación estándar de la frecuencia del segundo formante (F2). Calculada usando el comando `Get standard deviation` de Praat para el segundo formante en Hertz. | `stdevF2 = pm.praat.call(formant, "Get standard deviation", 2, xmin, xmax, "Hertz")` |
| **`f3_p`**   | Frecuencia del tercer formante (F3) en el período de análisis. Calculada usando el comando `Get quantile...` de Praat para obtener el percentil 50 (mediana) de F3 en Hertz. | `f3_p = pm.praat.call(formant, "Get quantile...", 3, xmin, xmax, "Hertz", 0.5)` |
| **`stdevF3`**| Desviación estándar de la frecuencia del tercer formante (F3). Calculada usando el comando `Get standard deviation` de Praat para el tercer formante en Hertz. | `stdevF3 = pm.praat.call(formant, "Get standard deviation", 3, xmin, xmax, "Hertz")` |
| **`stdevF0`**| Desviación estándar de la frecuencia fundamental (F0). Calculada usando el comando `Get standard deviation` de Praat en Hertz. | `stdevF0 = pm.praat.call(pitch, "Get standard deviation", xmin, xmax, "Hertz")` |
| **`fdisp`**  | Dispersión de las frecuencias de los formantes. Calculada como la diferencia entre la frecuencia del cuarto formante (F4) y la del primer formante (F1), dividida entre 3. | `fdisp = (f4_p - f1_p) / 3` |
| **`mff`**    | Frecuencia media de formantes. Calculada como la raíz cuarta del producto de las frecuencias del primer, segundo, tercer y cuarto formante. | `mff = (f1_p * f2_p * f3_p * f4_p) ** 0.25` |
| **`meanF0`** | Frecuencia fundamental media (F0) en el período de análisis. Calculada usando el comando `Get mean...` de Praat para obtener la media de F0 en Hertz. | `meanF0 = pm.praat.call(pitch, "Get mean...", xmin, xmax, "Hertz")` |
| **`coefP`**  | Coeficiente de predicción, representado como un porcentaje de la desviación estándar de la frecuencia fundamental (F0) respecto a su media. | `coefP = 100 * (stdevF0 / meanF0)` |

# %% [markdown]
# | **Variable** | **Definición** | **Fórmula** |
# |--------------|----------------|-------------|
# | **`f0_p`**   | Frecuencia fundamental (F0) en el período de análisis. Calculada usando el comando `Get quantile...` de Praat para obtener el percentil 50 (mediana) de la frecuencia fundamental en Hertz. | `f0_p = pm.praat.call(pitch, "Get quantile...", xmin, xmax, 0.5, "Hertz")` |
# | **`f1_p`**   | Frecuencia del primer formante (F1) en el período de análisis. Calculada usando el comando `Get quantile...` de Praat para obtener el percentil 50 (mediana) de F1 en Hertz. | `f1_p = pm.praat.call(formant, "Get quantile...", 1, xmin, xmax, "Hertz", 0.5)` |
# | **`stdevF1`**| Desviación estándar de la frecuencia del primer formante (F1). Calculada usando el comando `Get standard deviation` de Praat para el primer formante en Hertz. | `stdevF1 = pm.praat.call(formant, "Get standard deviation", 1, xmin, xmax, "Hertz")` |
# | **`f2_p`**   | Frecuencia del segundo formante (F2) en el período de análisis. Calculada usando el comando `Get quantile...` de Praat para obtener el percentil 50 (mediana) de F2 en Hertz. | `f2_p = pm.praat.call(formant, "Get quantile...", 2, xmin, xmax, "Hertz", 0.5)` |
# | **`stdevF2`**| Desviación estándar de la frecuencia del segundo formante (F2). Calculada usando el comando `Get standard deviation` de Praat para el segundo formante en Hertz. | `stdevF2 = pm.praat.call(formant, "Get standard deviation", 2, xmin, xmax, "Hertz")` |
# | **`f3_p`**   | Frecuencia del tercer formante (F3) en el período de análisis. Calculada usando el comando `Get quantile...` de Praat para obtener el percentil 50 (mediana) de F3 en Hertz. | `f3_p = pm.praat.call(formant, "Get quantile...", 3, xmin, xmax, "Hertz", 0.5)` |
# | **`stdevF3`**| Desviación estándar de la frecuencia del tercer formante (F3). Calculada usando el comando `Get standard deviation` de Praat para el tercer formante en Hertz. | `stdevF3 = pm.praat.call(formant, "Get standard deviation", 3, xmin, xmax, "Hertz")` |
# | **`stdevF0`**| Desviación estándar de la frecuencia fundamental (F0). Calculada usando el comando `Get standard deviation` de Praat en Hertz. | `stdevF0 = pm.praat.call(pitch, "Get standard deviation", xmin, xmax, "Hertz")` |
# | **`fdisp`**  | Dispersión de las frecuencias de los formantes. Calculada como la diferencia entre la frecuencia del cuarto formante (F4) y la del primer formante (F1), dividida entre 3. | `fdisp = (f4_p - f1_p) / 3` |
# | **`mff`**    | Frecuencia media de formantes. Calculada como la raíz cuarta del producto de las frecuencias del primer, segundo, tercer y cuarto formante. | `mff = (f1_p * f2_p * f3_p * f4_p) ** 0.25` |
# | **`meanF0`** | Frecuencia fundamental media (F0) en el período de análisis. Calculada usando el comando `Get mean...` de Praat para obtener la media de F0 en Hertz. | `meanF0 = pm.praat.call(pitch, "Get mean...", xmin, xmax, "Hertz")` |
# | **`coefP`**  | Coeficiente de predicción, representado como un porcentaje de la desviación estándar de la frecuencia fundamental (F0) respecto a su media. | `coefP = 100 * (stdevF0 / meanF0)` |
