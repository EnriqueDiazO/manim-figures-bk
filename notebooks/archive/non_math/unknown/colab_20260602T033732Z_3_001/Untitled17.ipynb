# %%
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# La salida anterior fue una cadena de texto:  **Hola mundo**

# %% [markdown]
# # **Hola a todos**

# %%
# prompt: print hello world using rot13

import codecs

def rot13(text):
    return codecs.encode(text, 'rot13')

print(rot13("Hello, World!"))
