# %%
# Escribe aquí tu solución del problema
# Problema 4
# Definir una función para mostrar información detallada del estudiante
#def my_funcion(nombre, edad, altura, es_estudiante):
#    # Convertir la entrada "Si" o "No" a booleano
#    if es_estudiante.title() == "Si":
#        es_estudiante = True
#    elif es_estudiante.title() == "No":
#        es_estudiante = False
#
#    # Verificar si se han proporcionado todos los datos necesarios
#    if isinstance(nombre, str) and isinstance(edad, int) and isinstance(altura, float) and isinstance(es_estudiante, bool):
#        # Mostrar información detallada del estudiante
#        print("Información del Estudiante:")
#        ...
#    else:
#        # Mostrar mensaje de error si falta algún dato o se proporciona incorrectamente
#        print("Error: Por favor, proporcione todos los datos necesarios correctamente.")
#        print(" Ejemplo: ('Juan', 25, 1.75, 'Si')")


def my_funcion(nombre, edad, altura, es_estudiante):
    es_estudiante = input("¿Es estudiante? (Si/No): ")
    # Convertir la entrada "Si" o "No" a booleano
    if es_estudiante.title() == "Si":
        es_estudiante = True
    elif es_estudiante.title() == "No":
        es_estudiante = False
    else:
        print("Error: Por favor, responda con 'Si' o 'No' para indicar si es estudiante.")
        #print(" Ejemplo: ('Juan', 25, 1.75, 'Si')")
        return
    #nombre = str(input("Ingrese el nombre del estudiante: "))

    nombre = input("Ingrese el nombre del estudiante bajo el siguiente formato ApellidoPaterno ApellidoMaterno Nombre: ")

    if nombre.strip() == "":
        print("Error: Por favor, introduzca el nombre del estudiante.")
        return
    elif not all(part.isalpha() for part in nombre.split()):
        print("Error: Por favor, introduzca el nombre completo del estudiante sin números (ApellidoPaterno ApellidoMaterno Nombre).")
        return
    #if not isinstance(nombre, str) or nombre.strip() == "":
    #    print("Error: Por favor, introduzca el nombre del estudiante.")
    #    print(" Ejemplo: ('Juan', 25, 1.75, 'Si')")
    #    return
    else:
        print("Información del Estudiante:")
        print("Nombre:", nombre)
    #edad = int(input("Ingrese la edad del estudiante (en años enteros): "))
    edad = input("Ingrese la edad del estudiante (en años enteros): ")
    try:
        edad = int(edad)
        print("Edad:", edad)
    except ValueError:
        print("Error: Por favor, proporcione la edad en años enteros.")
        print(" Ejemplo: ('Juan', 25, 1.75, 'Si')")
        return

    altura = input("Ingrese la altura del estudiante en metros (con o sin decimales): ")
    try:
        altura = float(altura)
        print("Altura:", altura)
    except ValueError:
        print("Error: Por favor, proporcione la altura en metros (con o sin decimales).")
        print(" Ejemplo: ('Juan', 25, 1.75, 'Si')")
        return
    else:
        print("Altura:", altura)
        print("¿Es estudiante?:", "Sí" if es_estudiante else "No")


# Ejemplo de llamada correcta
my_funcion('Juan', 25, 1.75, 'Sí')
# Out:
# Error: Por favor, introduzca el nombre completo del estudiante sin números (ApellidoPaterno ApellidoMaterno Nombre).

# %%
#
