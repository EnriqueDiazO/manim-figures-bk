# %%
# !git clone https://github.com/EnriqueDiazO/excel_pandas_proyect.git
# Out:
# Cloning into 'excel_pandas_proyect'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 39 (delta 9), reused 32 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (39/39), 12.81 MiB | 9.55 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
# %cd excel_pandas_proyect
# Out:
# /content/excel_pandas_proyect

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 68.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 59.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 29.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 64.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 26.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.4/95.4 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.9/425.9 kB 15.3 MB/s eta 0:00:00
# ...

# %%
# %cd excel_pandas_proyect
# Out:
# /content/excel_pandas_proyect

# %%
from excel_pandas.libro import LibroPandas
libro = LibroPandas("MiLibro")

# %%
# %pwd
# Out:
# '/content/excel_pandas_proyect'

# %%
from excel_pandas.libro import LibroPandas

# Crear un libro desde archivo Excel
libro = LibroPandas.desde_excel("data/articulos_limpios.xlsx")

# Acceder a una hoja
hoja = libro.obtener_hoja("BibTeX")

# Ver las primeras filas
print(hoja.head())

# Analizar texto con HojaSemantica
from excel_pandas.hoja_semantica import HojaSemantica
hoja_sem = HojaSemantica(hoja)
hoja_sem.analizar_texto("Abstract")
hoja_sem.graficar_clusters()
# Out:
#  Hoja: 'BibTeX'
#               ID     Type                                              Title  \
# 0  Kherdekar2024  article  Integrated approaches for plastic waste manage...
# 1     Howard2007  article  Effect of insertional mutations in the pueA an...
# 2     Bryant2016  article  Diversity and Activity of Communities Inhabiti...
# 3    Maclean2021  article  The terrestrial plastisphere: Diversity and po...
# 4      Danso2018  article  crossm New Insights into the Function and Glob...
#
#                                            Author(s)  Year  \
# 0         Kherdekar, Rajkumar D. and Ade, Avinash B.  2024
# 1  Howard, G. T. and Mackie, R. I. and Cann, I. K...  2007
# 2  Bryant, Jessica A. and Clemente, Tara M. and V...  2016
# 3  Maclean, Joana and Mayanna, Sathish and Bennin...  2021
# 4  Danso, Dominik and Chow, Jennifer and Zimmerma...  2018
#
#                            Journal  Volume          Number       Pages  \
# ...

# %%
print(libro)
# Out:
#  Libro: articulos_limpios, hojas: ['BibTeX', 'ClusterTFIDF']
