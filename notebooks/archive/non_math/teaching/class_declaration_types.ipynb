# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass
class AudioJob:
    path: Path
    speakers: int

job = AudioJob(7, "dos")  # Python no protesta
print(job)  # AudioJob(path=7, speakers='dos')
# Out:
# AudioJob(path=7, speakers='dos')

# %%
audio.path
# Out:
# 7

# %%
audio.speakers
# Out:
# 8

# %%
class AudioJob:
    path: Path
    speakers: int

# %%
audio = AudioJob()

# %%
audio.path="."

# %%
audio.speakers=2

# %%
print(audio)

# %%
audio.speakers
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-4061166680.py in <cell line: 0>()
# ----> 1 audio.speakers
#
# AttributeError: 'AudioJob' object has no attribute 'speakers'
