# %% [markdown]
# # MÓDULO I. Fundamentos y estructura del lenguaje Python.

# %% [markdown]
# # Objetivo General del Módulo 1
# ## Capacitar en fundamentos y estructura de Python.
#
# # Objetivos específicos del Módulo 1
# - Comprender sintaxis, operaciones básicas, manejo de variables, control de flujo, alcance de variables.
# - Introducir herramientas como Pip, comprensiones, generadores.

# %% [markdown]
# # Glosario en términos del objetivo general del módulo 1.
#
# ## Capacitar:
# Proceso de proporcionar conocimientos, habilidades y recursos a individuos o grupos con el fin de mejorar su desempeño en un área específica.
#
# ## Sintaxis:
# Estructura y reglas básicas de escritura de código Python, incluyendo variables, asignaciones, expresiones y comentarios.
#
# ## Operaciones básicas:
# Dominio de operaciones aritméticas, de comparación y lógicas en Python para manipular datos y realizar cálculos.
#
# ## Manejo de variables:
# Declaración, asignación y manipulación de variables en Python, comprendiendo diferentes tipos de datos y su manejo.
#
# ## Control de flujo:
# Dominio de estructuras de control como condicionales (if, else) y bucles (for, while) para dirigir el flujo del programa.
#
# ## Alcance de variables:
# Entender el concepto de alcance en Python, incluyendo variables locales, globales y de ámbito adjunto para escribir código modular y evitar conflictos de nombres.
#
# ## Pip:
# Gestor de paquetes en Python, que facilita la instalación, actualización y eliminación de paquetes de manera eficiente para facilitar el desarrollo y la gestión de dependencias.
#
# ## Comprensiones/generadores:
# Crear estructuras de datos de manera concisa y eficiente, así como generar secuencias de datos bajo demanda, mejorando la legibilidad y el rendimiento del código.

# %% [markdown]
# # Objetivos por Tema:
#
# ## Tema 1. Introducción:
#
# - Introducir a los estudiantes en el lenguaje de programación Python, sus áreas de aplicación, diferencias entre Python 2 y Python 3, así como enseñarles los procedimientos de instalación y configuración del entorno de desarrollo, incluyendo su integración con Visual Studio Code y Jupyter.
#
#
# ## Tema 2. Pip:
#
# - Capacitar a los estudiantes en el uso de Pip como gestor de paquetes en Python, permitiéndoles listar, actualizar, desinstalar paquetes, crear archivos de requisitos y manejar paquetes externos mediante wheel.
#
#
# ## Tema 3. Módulo, paquetes y namespaces:
#
# - Explorar los conceptos de módulos, paquetes y namespaces en Python, brindando a los estudiantes una comprensión sólida de cómo organizar y estructurar sus programas.

# %% [markdown]
# ----------------------------------

# %% [markdown]
# # Tema 1. Introducción
#
# ## 1.1. Lenguaje de Programación Python.
#
# Python es un lenguaje de programación:
#
# - **De alto nivel:** Significa que está diseñado para ser fácil de leer y escribir para los humanos. Su sintaxis es clara y concisa, lo que facilita la comprensión del código. Esto permite a los programadores enfocarse en la lógica del problema en lugar de preocuparse por detalles de bajo nivel.
#
# - **Interpretado:** En lugar de compilar el código a un lenguaje de máquina antes de ejecutarlo, como lo hacen los lenguajes compilados, Python utiliza un intérprete que ejecuta el código directamente. Esto significa que puedes escribir y probar código Python rápidamente sin necesidad de esperar por un proceso de compilación.
#
# - **De propósito general:** Python se puede utilizar para una amplia variedad de tareas y aplicaciones. Desde el desarrollo de sitios web y aplicaciones de escritorio hasta el análisis de datos, la automatización de tareas y la inteligencia artificial, Python es una herramienta versátil que se adapta a numerosos contextos y proyectos.

# %% [markdown]
# ---

# %% [markdown]
# ## 1.2. Áreas de aplicación de Python.
#
# Python es un lenguaje de programación versátil que se utiliza en una amplia variedad de aplicaciones, incluyendo:
#
# 1. **Desarrollo web:** Frameworks como Django y Flask permiten desarrollar aplicaciones web robustas y escalables.
#
# 2. **Aplicaciones de escritorio:** Con bibliotecas como Tkinter, PyQt y wxPython, Python se utiliza para crear interfaces de usuario (UI) intuitivas y funcionales.
#
# 3. **Análisis de datos:** Bibliotecas como Pandas, NumPy y Matplotlib hacen que Python sea una opción popular para análisis y visualización de datos.
#
# 4. **Inteligencia artificial y machine learning:** Con herramientas como TensorFlow, PyTorch y scikit-learn, Python se utiliza para desarrollar modelos de machine learning y aplicaciones de inteligencia artificial.
#
# 5. **Automatización de tareas:** Python es ampliamente utilizado para automatizar tareas repetitivas y procesos de flujo de trabajo en sistemas informáticos, administración de servidores, administración de redes, entre otros.
#
# 6. **Desarrollo de juegos:** A través de bibliotecas como Pygame y Pyglet, Python se utiliza en el desarrollo de juegos tanto para entretenimiento como para educación.
#
# 7. **Desarrollo de aplicaciones móviles:** Frameworks como Kivy permiten desarrollar aplicaciones móviles multiplataforma utilizando Python.
#
# 8. **Procesamiento de imágenes y visión por computadora:** Con bibliotecas como OpenCV y scikit-image, Python se utiliza para el procesamiento de imágenes, reconocimiento de objetos y visión por computadora.

# %% [markdown]
# ## 1.3 Python 2 vs Python 3.
#
# | Característica          | Python 2                                     | Python 3                                     |
# |-------------------------|----------------------------------------------|----------------------------------------------|
# | Soporte                 | Finalizó el 1 de enero de 2020.             | Activo, con nuevas versiones y actualizaciones frecuentes.|
# | Sintaxis Unicode        | No es la predeterminada.                    | La cadena de texto es Unicode por defecto.     |
# | Función print           | Sintaxis: `print "texto"`                   | Sintaxis: `print("texto")`                    |
# | División entera         | El operador `/` realiza la división entera. | El operador `//` realiza la división entera. |
# | Manejo de excepciones   | `except Exception, e:`                      | `except Exception as e:`                      |
# | xrange()                | Existe.                                      | Reemplazado por `range()`.                    |
# | input()                 | Interpreta la entrada como código Python.    | Lee la entrada como una cadena de texto.      |
# | Iteradores y generadores| `next()` y `.__next__()` para iteradores.   | `next()` y `.__next__()` para iteradores.    |
# | Biblioteca estándar     | No siempre es compatible con Unicode.        | Compatible con Unicode.                       |

# %% [markdown]
# | Motivaciones para migrar a Python 3                                         | Razones para seguir utilizando Python 2.7                           |
# |------------------------------------------------------------------------------|---------------------------------------------------------------------|
# | Mejoras en el lenguaje y la biblioteca estándar, incluyendo una mejor gestión de Unicode, mejoras en la manipulación de cadenas de texto, nuevas características sintácticas y semánticas, entre otras. | Código heredado: Muchos proyectos y sistemas existentes están escritos en Python 2.7 y pueden requerir esfuerzos significativos para migrar a Python 3. Esto puede ser especialmente cierto para proyectos grandes o antiguos con una gran base de código. |
# | Compatibilidad con Unicode por defecto: Python 3 adoptó Unicode como el tipo de cadena predeterminado, lo que facilita el trabajo con diferentes conjuntos de caracteres y mejora el soporte para idiomas no occidentales. | Dependencias de bibliotecas: Algunas bibliotecas de terceros pueden no ser compatibles con Python 3 o pueden tener versiones que aún dependen de Python 2.7. Esto puede dificultar la migración de proyectos que utilizan estas bibliotecas. |
# | Eliminación de características obsoletas y redundantes de Python 2, lo que simplificó el lenguaje y mejoró su consistencia. | Costo de la migración: La migración de código de Python 2 a Python 3 puede requerir tiempo, recursos y pruebas extensas para garantizar que el código migrado funcione correctamente. Para algunas organizaciones, esto puede ser un proceso costoso y complejo. |
# | Soporte a largo plazo: Python 2 alcanzó su final de vida útil el 1 de enero de 2020, lo que significa que ya no recibe actualizaciones ni soporte oficial de la comunidad de Python. Por lo tanto, migrar a Python 3 garantiza el soporte continuo y acceso a nuevas características y mejoras. | Falta de conciencia o resistencia al cambio: Algunas personas y organizaciones pueden no estar completamente conscientes de la importancia de migrar a Python 3 o pueden resistirse al cambio debido a la familiaridad con Python 2.7 y la renuencia a invertir en la migración. |

# %% [markdown]
# # 1.4. Instalación Python y Configuración.
# ![Logo de Anaconda](https://elpythonista.com/wp-content/uploads/2020/10/Anaconda-entrada-hd.jpg)
#
# La **Distribución Anaconda** es una distribución gratuita de Python/R para ciencia de datos que contiene:
#
# - **conda:** un administrador de paquetes y entornos para tu interfaz de línea de comandos.
# - **Anaconda Navigator:** una aplicación de escritorio construida sobre conda, con opciones para iniciar otras aplicaciones de desarrollo desde tus entornos gestionados.
# - Más de **250 paquetes científicos y de aprendizaje automático.**
#
# La **Distribución Anaconda** es gratuita, fácil de instalar y ofrece soporte comunitario gratuito.
#
# - [Instalación de Anaconda en Windows](https://docs.anaconda.com/free/anaconda/install/windows/)
# - [Instalación de Anaconda en Linux](https://docs.anaconda.com/free/anaconda/install/linux/)
# - [Instalación de Anaconda en MAC](https://docs.anaconda.com/free/anaconda/install/mac-os/)

# %% [markdown]
# ### 1.5. Ejecución de Programa de Python.
#
# En esta sección se aborda el proceso de ejecución de un programa escrito en Python. Se exploran los pasos necesarios para ejecutar un script de Python en diferentes entornos, como la línea de comandos o un entorno de desarrollo integrado (IDE). Además, se discuten posibles problemas de ejecución y cómo solucionarlos.

# %%
# Este es un ejemplo básico de un script en Python que imprime un mensaje.

mensaje = "Hola, mundo!"
print(mensaje)
# Out:
# Hola, mundo!

# %% [markdown]
# ### 1.6. Python con Visual Studio Code.
# ![Logo de Visual Studio](https://code.visualstudio.com/assets/docs/getstarted/userinterface/hero.png)
#
# Visual Studio Code (VS Code) es un editor de código fuente ligero pero potente que se ejecuta en tu escritorio y está disponible para Windows, macOS y Linux. Viene con soporte incorporado para JavaScript, TypeScript y Node.js, y tiene un ecosistema rico en extensiones para otros lenguajes y entornos de ejecución (como C++, C#, Java, Python, PHP, Go, .NET). Inicia tu viaje con VS Code con estos vídeos introductorios.
#
# #### Por qué usar VS Code:
#
# 1. **Ligero y potente**: A pesar de ser ligero en recursos, VS Code es extremadamente potente y ofrece muchas características avanzadas para mejorar la productividad del desarrollador.
#
# 2. **Multiplataforma**: Disponible para Windows, macOS y Linux, lo que permite a los desarrolladores trabajar en su plataforma preferida.
#
# 3. **Amplia compatibilidad de lenguajes**: Viene con soporte integrado para varios lenguajes de programación y tiene una amplia gama de extensiones disponibles para otros lenguajes y entornos de ejecución.
#
# 4. **Integración con Git**: Ofrece una integración perfecta con Git, lo que facilita el seguimiento de cambios en el código y la colaboración en proyectos de equipo.
#
# 5. **Extensibilidad**: VS Code es altamente personalizable a través de extensiones, lo que te permite adaptarlo a tus necesidades específicas de desarrollo.
#
#
#
#
#
#
# [Instalar Visual Studio](https://code.visualstudio.com/)

# %% [markdown]
# ## 1.7. Python con Júpiter.
# ![Logo de Jupyter Notebook ](https://miro.medium.com/v2/resize:fit:720/format:webp/1*RzxZF0mmXAsMLrIzAWYDSg.png)
#
# Jupyter Notebook es una aplicación web de código abierto permite crear y compartir documentos interactivos que contienen código, ecuaciones, visualizaciones y texto narrativo. Algunas de sus características principales incluyen:
#
# - **Interactividad:** Jupyter Notebook permite ejecutar código en vivo en diferentes lenguajes de programación, incluyendo Python, R, Julia y muchos más. Esto significa que puedes escribir y ejecutar código en celdas individuales, ver los resultados de inmediato y hacer ajustes sobre la marcha.
#
# - **Facilidad de uso:** Su interfaz intuitiva y basada en el navegador facilita la creación y edición de documentos. Puedes incluir texto enriquecido, ecuaciones LaTeX, imágenes y videos, además de código ejecutable, todo en un solo documento.
#
# - **Visualizaciones interactivas:** Jupyter Notebook admite una amplia gama de bibliotecas de visualización de datos, como matplotlib, seaborn y bokeh, lo que te permite crear gráficos y diagramas interactivos directamente en tus documentos.
#
#
# - **Compartibilidad:** Los documentos de Jupyter Notebook se pueden compartir fácilmente con otros a través de correo electrónico, Dropbox, GitHub y otras plataformas. También puedes convertir tus notebooks a diferentes formatos, como HTML, PDF o presentaciones de diapositivas, para compartirlos de manera más amplia.
#
# [Instalar Jupyter Notebook](https://test-jupyter.readthedocs.io/en/latest/install.html#installing-jupyter-using-anaconda-and-conda)

# %% [markdown]
# ### 1.8. Estructura principal del Lenguaje.
#
# En esta sección, exploraremos la estructura principal del lenguaje Python. Esto incluye los elementos básicos que componen un programa en Python, como las declaraciones de importación, definición de funciones, condicionales, bucles y manejo de errores.
#
# La comprensión de esta estructura es fundamental para cualquier programador de Python, ya que sienta las bases para escribir código claro, legible y eficiente.
#
# | Elemento               | Descripción                                                                                            |
# |------------------------|--------------------------------------------------------------------------------------------------------|
# | Declaraciones de importación | Permiten importar módulos y funciones externas para utilizarlas en el programa.                         |
# | Definición de funciones    | Permite definir bloques de código reutilizables que realizan una tarea específica.                      |
# | Condicionales              | Estructuras de control que permiten ejecutar diferentes bloques de código según una condición dada.    |
# | Bucles                     | Estructuras de control que permiten repetir la ejecución de un bloque de código varias veces.          |
# | Manejo de errores          | Permite manejar excepciones y errores que pueden ocurrir durante la ejecución del programa.            |

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# --------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Tema 2: Pip
# ## 2.1. PyPI Package Manager
#
# PyPI (Python Package Index) es el repositorio oficial de paquetes de software para Python. Pip (Python Install Package) es una herramienta utilizada para instalar y administrar paquetes desde PyPI.
# ## 2.2. Listar todos los paquetes instalados usando pip
#
# Para listar todos los paquetes instalados en tu sistema, puedes ejecutar el siguiente comando en tu terminal:

# %%
import

# %%
#Listado de Paquetes Instalados
# !pip list
# Out:
# Package                       Version
# ----------------------------- ---------------
# absl-py                       1.2.0
# aiofiles                      23.2.1
# aiohttp                       3.9.1
# aiosignal                     1.3.1
# alabaster                     0.7.12
# alembic                       1.8.1
# altair                        5.1.2
# altgraph                      0.17.4
# anaconda-anon-usage           0.4.4
# anaconda-client               1.12.3
# anaconda-navigator            2.4.2
# annotated-types               0.6.0
# antlr4-python3-runtime        4.9.3
# anyio                         3.7.1
# appdirs                       1.4.4
# apricot-select                0.6.1
# argon2-cffi                   21.3.0
# argon2-cffi-bindings          21.2.0
# arrow                         1.2.3
# astroid                       2.14.2
# astropy                       5.3.4
# asttokens                     2.0.5
# astunparse                    1.6.3
# async-lru                     2.0.4
# async-timeout                 4.0.3
# atomicwrites                  1.4.0
# attrs                         23.1.0
# audioread                     3.0.0
# Automat                       20.2.0
# autopep8                      2.0.4
# Babel                         2.11.0
# backcall                      0.2.0
# backports.functools-lru-cache 1.6.4
# backports.tempfile            1.0
# backports.weakref             1.0.post1
# bcrypt                        3.2.0
# beautifulsoup4                4.12.2
# binaryornot                   0.4.4
# bitarray                      2.5.1
# bkcharts                      0.2
# black                         24.3.0
# bleach                        4.1.0
# blis                          0.7.11
# bokeh                         3.4.0
# boltons                       23.0.0
# boto3                         1.34.82
# botocore                      1.34.82
# Bottleneck                    1.3.7
# Brotli                        1.0.9
# cachetools                    5.3.0
# catalogue                     2.0.10
# category-encoders             2.6.3
# certifi                       2024.2.2
# cffi                          1.15.1
# chardet                       4.0.0
# charset-normalizer            2.0.4
# clarabel                      0.8.1
# click                         8.1.7
# click-plugins                 1.1.1
# cligj                         0.7.2
# cloudpathlib                  0.16.0
# cloudpickle                   2.2.1
# clyent                        1.2.2
# colorama                      0.4.6
# colorcet                      3.1.0
# comm                          0.2.1
# conda                         23.3.1
# conda-build                   3.23.3
# conda-content-trust           0.2.0
# conda-package-handling        2.2.0
# conda_package_streaming       0.9.0
# conda-repo-cli                1.0.88
# conda-token                   0.4.0
# conda-verify                  3.4.2
# confection                    0.1.4
# config                        0.5.1
# constantly                    23.10.4
# contourpy                     1.2.0
# cookiecutter                  2.6.0
# cryptography                  41.0.3
# cssselect                     1.2.0
# cvxpy                         1.5.1
# cycler                        0.11.0
# cymem                         2.0.8
# Cython                        3.0.10
# cytoolz                       0.12.2
# daal4py                       2023.1.1
# dash                          2.17.0
# dash-core-components          2.0.0
# dash-html-components          2.0.0
# dash-table                    5.0.0
# dask                          2022.2.1
# databricks-cli                0.17.4
# datashader                    0.16.0
# debugpy                       1.6.7
# decorator                     4.4.2
# defusedxml                    0.7.1
# diff-match-patch              20200713
# dill                          0.3.7
# distributed                   2022.2.1
# dnspython                     2.3.0
# docker                        6.0.1
# docopt                        0.6.2
# docstring-to-markdown         0.11
# docutils                      0.18.1
# easyocr                       1.7.1
# EasyProcess                   1.1
# ecos                          2.0.13
# entrypoint2                   1.1
# entrypoints                   0.4
# es-core-news-sm               3.7.0
# et-xmlfile                    1.1.0
# exceptiongroup                1.1.3
# executing                     0.8.3
# fairseq                       0.12.2
# falcon                        3.1.1
# falcon-cors                   1.1.7
# fastapi                       0.104.1
# fastjsonschema                2.16.2
# ffmpy                         0.3.1
# filelock                      3.13.1
# fiona                         1.9.6
# flake8                        7.0.0
# Flask                         2.2.5
# flatbuffers                   24.3.25
# fonttools                     4.51.0
# frozendict                    2.4.4
# frozenlist                    1.4.1
# fsspec                        2024.3.1
# fst-pso                       1.8.1
# future                        0.18.3
# FuzzyTM                       2.0.5
# fuzzywuzzy                    0.18.0
# gast                          0.4.0
# gensim                        4.3.0
# geographiclib                 2.0
# geopandas                     0.14.4
# geopy                         2.4.1
# gitdb                         4.0.10
# GitPython                     3.1.29
# glob2                         0.7
# gmpy2                         2.1.2
# google                        3.0.0
# google-api-core               2.11.0
# google-auth                   2.16.1
# google-auth-oauthlib          0.4.6
# google-cloud                  0.34.0
# google-cloud-speech           2.17.3
# google-pasta                  0.2.0
# googleapis-common-protos      1.58.0
# gradio                        4.0.2
# gradio_client                 0.7.0
# greenlet                      3.0.1
# grpcio                        1.51.3
# grpcio-status                 1.51.3
# gunicorn                      20.1.0
# h11                           0.14.0
# h5py                          3.11.0
# HeapDict                      1.0.1
# holoviews                     1.18.3
# html5lib                      1.1
# httpcore                      1.0.1
# httpx                         0.25.1
# huggingface-hub               0.20.3
# hvplot                        0.9.2
# hydra-core                    1.0.7
# hyperlink                     21.0.0
# idna                          3.7
# imagecodecs                   2023.1.23
# imageio                       2.33.1
# imageio-ffmpeg                0.4.8
# imagesize                     1.4.1
# importlib-metadata            7.0.1
# importlib-resources           6.1.1
# incremental                   22.10.0
# inflection                    0.5.1
# iniconfig                     1.1.1
# intake                        0.6.8
# intervaltree                  3.1.0
# ipykernel                     6.25.0
# ipython                       8.15.0
# ipython-genutils              0.2.0
# ipywidgets                    8.1.2
# isort                         5.9.3
# itemadapter                   0.3.0
# itemloaders                   1.1.0
# itsdangerous                  2.0.1
# jams                          0.3.4
# jaraco.classes                3.2.1
# jdcal                         1.4.1
# jedi                          0.18.1
# jeepney                       0.7.1
# jellyfish                     1.0.1
# Jinja2                        3.1.3
# jmespath                      1.0.1
# joblib                        1.4.0
# Js2Py                         0.71
# json5                         0.9.6
# jsonpatch                     1.33
# jsonpointer                   2.1
# jsonschema                    4.19.2
# jsonschema-specifications     2023.7.1
# jupyter                       1.0.0
# jupyter_client                8.6.0
# jupyter-console               6.6.3
# jupyter_core                  5.5.0
# jupyter-events                0.8.0
# jupyter-lsp                   2.2.0
# jupyter_server                2.10.0
# jupyter_server_terminals      0.4.4
# jupyterlab                    4.0.11
# jupyterlab-pygments           0.1.2
# jupyterlab_server             2.25.1
# jupyterlab-widgets            3.0.10
# kaggle                        1.6.12
# kaleido                       0.2.1
# keras                         3.3.3
# Keras-Preprocessing           1.1.2
# keyring                       24.3.1
# kiwisolver                    1.4.4
# langcodes                     3.3.0
# lazy_loader                   0.3
# lazy-object-proxy             1.10.0
# Levenshtein                   0.21.1
# libarchive-c                  2.9
# libclang                      14.0.6
# librosa                       0.10.2.post1
# lightning-utilities           0.10.1
# linkify-it-py                 2.0.0
# llvmlite                      0.42.0
# lmdb                          1.4.1
# locket                        1.0.0
# lxml                          4.9.3
# Mako                          1.2.4
# Markdown                      3.4.1
# markdown-it-py                2.2.0
# MarkupSafe                    2.1.3
# matplotlib                    3.8.4
# matplotlib-inline             0.1.6
# mccabe                        0.7.0
# mdit-py-plugins               0.3.0
# mdurl                         0.1.0
# miniful                       0.0.6
# mir-eval                      0.7
# mistune                       2.0.4
# mizani                        0.9.2
# mkl-service                   2.4.0
# ml-dtypes                     0.3.2
# mlflow                        2.0.1
# mlxtend                       0.23.1
# more-itertools                10.1.0
# MouseInfo                     0.1.3
# moviepy                       1.0.3
# mpmath                        1.3.0
# msgpack                       1.0.3
# mss                           9.0.1
# multidict                     6.0.4
# multipledispatch              0.6.0
# multitasking                  0.0.11
# murmurhash                    1.0.10
# my-voice-analysis             0.7
# mypy-extensions               1.0.0
# mysql-connector-python        8.4.0
# namex                         0.0.8
# navigator-updater             0.2.1
# nbclient                      0.8.0
# nbconvert                     7.16.4
# nbformat                      5.10.4
# nest-asyncio                  1.6.0
# networkx                      3.1
# ninja                         1.11.1.1
# nltk                          3.8.1
# nose                          1.3.7
# notebook                      7.0.8
# notebook-as-pdf               0.5.0
# notebook_shim                 0.2.3
# numba                         0.59.1
# numexpr                       2.8.7
# numpy                         1.26.4
# numpydoc                      1.5.0
# nvidia-cublas-cu11            11.10.3.66
# nvidia-cuda-nvrtc-cu11        11.7.99
# nvidia-cuda-runtime-cu11      11.7.99
# nvidia-cudnn-cu11             8.5.0.96
# oauthlib                      3.2.0
# olefile                       0.46
# omegaconf                     2.3.0
# openai                        1.2.0
# opencv-python                 4.6.0.66
# opencv-python-headless        4.8.1.78
# openpyxl                      3.1.2
# opt-einsum                    3.3.0
# optree                        0.11.0
# orion                         0.2.6
# orjson                        3.9.10
# osqp                          0.6.5
# overrides                     7.4.0
# packaging                     23.2
# pandas                        2.2.1
# pandas-datareader             0.10.0
# pandocfilters                 1.5.0
# panel                         1.4.2
# param                         2.1.0
# parsel                        1.8.1
# parso                         0.8.3
# partd                         1.4.1
# pathspec                      0.10.3
# patsy                         0.5.3
# pdfminer.six                  20231228
# peewee                        3.17.5
# pep8                          1.7.1
# pexpect                       4.8.0
# pgmpy                         0.1.24
# pickleshare                   0.7.5
# pillow                        10.3.0
# pip                           23.3.1
# pipwin                        0.5.2
# pkginfo                       1.9.6
# platformdirs                  3.10.0
# plotly                        5.19.0
# plotnine                      0.12.2
# pluggy                        1.0.0
# ply                           3.11
# pmdarima                      2.0.4
# pomegranate                   1.0.3
# pooch                         1.8.1
# portalocker                   2.8.2
# praat-parselmouth             0.5.0.dev0
# praatio                       6.2.0
# preshed                       3.0.9
# proglog                       0.1.10
# prometheus-client             0.14.1
# prompt-toolkit                3.0.43
# Protego                       0.1.16
# proto-plus                    1.22.2
# protobuf                      4.25.3
# psutil                        5.9.0
# ptyprocess                    0.7.0
# pure-eval                     0.2.2
# py                            1.11.0
# py-cpuinfo                    9.0.0
# pyaml                         21.10.1
# pyarrow                       16.0.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# PyAudio                       0.2.11
# PyAutoGUI                     0.9.54
# pyclipper                     1.3.0.post5
# pycodestyle                   2.11.1
# pycosat                       0.6.6
# pycparser                     2.21
# pyct                          0.5.0
# pycurl                        7.45.2
# pydantic                      2.4.2
# pydantic_core                 2.10.1
# PyDispatcher                  2.0.5
# pydocstyle                    6.3.0
# pydub                         0.25.1
# pyee                          11.1.0
# pyerfa                        2.0.0
# pyflakes                      3.2.0
# pyFUME                        0.2.25
# PyGetWindow                   0.0.9
# Pygments                      2.15.1
# pyinstaller                   6.8.0
# pyinstaller-hooks-contrib     2024.7
# pyjsparser                    2.7.1
# PyJWT                         2.4.0
# pylint                        2.16.2
# pylint-venv                   3.0.3
# pyls-spyder                   0.4.0
# pymongo                       4.3.3
# PyMsgBox                      1.0.9
# pynput                        1.7.3
# pyodbc                        5.0.1
# pyOpenSSL                     23.2.0
# pyparsing                     3.0.9
# PyPDF2                        3.0.1
# pyperclip                     1.8.2
# pyportfolioopt                1.5.5
# pyppeteer                     2.0.0
# PyPrind                       2.11.3
# pyproj                        3.6.1
# PyQt5                         5.15.10
# PyQt5-sip                     12.13.0
# PyQtWebEngine                 5.15.6
# pyreadstat                    1.2.6
# PyRect                        0.2.0
# pyscreenshot                  3.1
# PyScreeze                     0.1.29
# pySmartDL                     1.3.4
# PySocks                       1.7.1
# PySoundFile                   0.9.0.post1
# pytest                        7.4.0
# python-bidi                   0.4.2
# python-dateutil               2.8.2
# python-json-logger            2.0.7
# python-Levenshtein            0.21.1
# python-lsp-black              2.0.0
# python-lsp-jsonrpc            1.1.2
# python-lsp-server             1.10.0
# python-multipart              0.0.6
# python-slugify                5.0.2
# python-snappy                 0.6.1
# python-xlib                   0.33
# python3-xlib                  0.15
# pytoolconfig                  1.2.6
# pytorch-lightning             2.0.9.post0
# pytorch-ranger                0.1.1
# pyts                          0.13.0
# pyttsx3                       2.90
# pytweening                    1.0.7
# pytz                          2024.1
# pytz-deprecation-shim         0.1.0.post0
# pyviz_comms                   3.0.2
# pywavelets                    1.5.0
# pyxdg                         0.27
# PyYAML                        6.0.1
# pyzmq                         25.1.2
# QDarkStyle                    3.2.3
# qdldl                         0.1.7.post2
# qstylizer                     0.2.2
# QtAwesome                     1.2.2
# qtconsole                     5.5.1
# QtPy                          2.4.1
# QuantStats                    0.0.62
# querystring-parser            1.2.4
# queuelib                      1.6.2
# rapidfuzz                     3.2.0
# referencing                   0.30.2
# regex                         2023.10.3
# reportlab                     4.1.0
# requests                      2.31.0
# requests-file                 1.5.1
# requests-oauthlib             1.3.1
# requests-toolbelt             1.0.0
# resampy                       0.4.0
# retrying                      1.3.4
# rfc3339-validator             0.1.4
# rfc3986-validator             0.1.1
# rich                          13.3.5
# rope                          1.12.0
# rpds-py                       0.10.6
# rsa                           4.9
# Rtree                         1.0.1
# ruamel.yaml                   0.17.21
# ruamel.yaml.clib              0.2.6
# ruamel-yaml-conda             0.17.21
# s3transfer                    0.10.1
# sacrebleu                     2.4.0
# safetensors                   0.4.2
# scikit-image                  0.22.0
# scikit-learn                  1.5.0
# scikit-learn-extra            0.3.0
# scikit-learn-intelex          20230426.111118
# scikit-optimize               0.9.0
# scipy                         1.11.4
# Scrapy                        2.11.1
# scs                           3.2.4.post1
# seaborn                       0.12.2
# SecretStorage                 3.3.1
# semantic-version              2.10.0
# Send2Trash                    1.8.2
# service-identity              18.1.0
# setuptools                    68.2.2
# setuptools-lint               0.6.0
# shap                          0.41.0
# shapely                       2.0.2
# shellingham                   1.5.4
# simpful                       2.11.1
# simplekml                     1.3.6
# sip                           6.7.12
# siuba                         0.4.2
# six                           1.16.0
# sklearn                       0.0.post1
# slicer                        0.0.7
# smart-open                    5.2.1
# smmap                         5.0.0
# sniffio                       1.3.0
# snowballstemmer               2.2.0
# sortedcollections             2.1.0
# sortedcontainers              2.4.0
# soundata                      0.1.2
# sounddevice                   0.4.5
# soundfile                     0.12.1
# soupsieve                     2.5
# soxr                          0.3.7
# spacy                         3.7.2
# spacy-legacy                  3.0.12
# spacy-loggers                 1.0.5
# SpeechRecognition             3.9.0
# Sphinx                        5.0.2
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        2.0.0
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.5
# spyder                        5.5.1
# spyder-kernels                2.5.0
# SQLAlchemy                    2.0.25
# sqlparse                      0.4.3
# srsly                         2.4.8
# stack-data                    0.2.0
# starlette                     0.27.0
# statsmodels                   0.14.0
# sympy                         1.12
# ta                            0.11.0
# tables                        3.9.2
# tabulate                      0.9.0
# TBB                           0.2
# tblib                         1.7.0
# tenacity                      8.2.2
# tensorboard                   2.16.2
# tensorboard-data-server       0.7.2
# tensorboard-plugin-wit        1.8.1
# tensorflow                    2.16.1
# tensorflow-estimator          2.9.0
# tensorflow-io-gcs-filesystem  0.26.0
# termcolor                     1.1.0
# terminado                     0.17.1
# testpath                      0.6.0
# text-unidecode                1.3
# textblob                      0.18.0.post0
# textdistance                  4.2.1
# tgt                           1.4.4
# thinc                         8.2.2
# threadpoolctl                 3.5.0
# three-merge                   0.1.1
# tifffile                      2023.4.12
# tinycss2                      1.2.1
# tk                            0.1.0
# tldextract                    3.2.0
# tokenizers                    0.15.1
# toml                          0.10.2
# tomli                         2.0.1
# tomlkit                       0.11.1
# toolz                         0.12.0
# torch                         1.11.0
# torch-optimizer               0.3.0
# torchaudio                    0.11.0
# torchmetrics                  1.3.0.post0
# torchvision                   0.14.1
# tornado                       6.3.3
# tqdm                          4.66.2
# traitlets                     5.7.1
# transformers                  4.37.2
# Twisted                       23.10.0
# typer                         0.9.0
# typing_extensions             4.8.0
# tzdata                        2023.3
# tzlocal                       4.2
# uc-micro-py                   1.0.1
# ujson                         5.4.0
# unicodedata2                  15.1.0
# Unidecode                     1.2.0
# urllib3                       1.26.18
# uvicorn                       0.23.2
# w3lib                         2.1.2
# wasabi                        1.1.2
# watchdog                      2.1.6
# wavencoder                    0.1.3
# wcwidth                       0.2.5
# weasel                        0.3.4
# webencodings                  0.5.1
# websocket-client              0.58.0
# websockets                    10.4
# Werkzeug                      2.2.3
# whatthepatch                  1.0.2
# wheel                         0.43.0
# widgetsnbextension            4.0.10
# wordcloud                     1.9.2
# wrapt                         1.11.2
# wurlitzer                     3.0.2
# xarray                        2023.6.0
# xlrd                          2.0.1
# XlsxWriter                    3.1.1
# xyzservices                   2022.9.0
# yapf                          0.40.2
# yarl                          1.9.4
# yfinance                      0.2.40
# zict                          3.0.0
# zipp                          3.17.0
# zope.interface                5.4.0
# zstandard                     0.22.0

# %% [markdown]
# ## 2.3. Actualizar Paquetes
#
# Para actualizar un paquete instalado a la última versión disponible, puedes usar el siguiente comando:

# %% [markdown]
# pip install --upgrade <nombre_del_paquete>

# %% [markdown]
# ## 2.4. Desinstalar Paquetes
#
# Para desinstalar un paquete, puedes utilizar el siguiente comando:

# %% [markdown]
# pip uninstall <nombre_del_paquete>

# %% [markdown]
# ## 2.5. Actualizar todos los paquetes obsoletos en Linux
# Para visualizar todos los paquetes obsoletos en un sistema Linux, puedes ejecutar el siguiente comando:

# %%
# !pip list --outdated
# Out:
# Package                       Version     Latest      Type
# ----------------------------- ----------- ----------- -----
# absl-py                       1.2.0       2.1.0       wheel
# aiofiles                      23.2.1      24.1.0      wheel
# aiohttp                       3.9.1       3.10.5      wheel
# alabaster                     0.7.12      0.7.16      wheel
# alembic                       1.8.1       1.13.2      wheel
# altair                        5.1.2       5.4.0       wheel
# annotated-types               0.6.0       0.7.0       wheel
# antlr4-python3-runtime        4.9.3       4.13.2      wheel
# anyio                         3.7.1       4.4.0       wheel
# argon2-cffi                   21.3.0      23.1.0      wheel
# arrow                         1.2.3       1.3.0       wheel
# astroid                       2.14.2      3.3.2       wheel
# astropy                       5.3.4       6.0.1       wheel
# asttokens                     2.0.5       2.4.1       wheel
# atomicwrites                  1.4.0       1.4.1       sdist
# attrs                         23.1.0      24.2.0      wheel
# audioread                     3.0.0       3.0.1       wheel
# Automat                       20.2.0      24.8.1      wheel
# autopep8                      2.0.4       2.3.1       wheel
# Babel                         2.11.0      2.16.0      wheel
# backports.functools-lru-cache 1.6.4       2.0.0       wheel
# bcrypt                        3.2.0       4.2.0       wheel
# beautifulsoup4                4.12.2      4.12.3      wheel
# bitarray                      2.5.1       2.9.2       wheel
# black                         24.3.0      24.8.0      wheel
# bleach                        4.1.0       6.1.0       wheel
# blis                          0.7.11      1.0.0       wheel
# bokeh                         3.4.0       3.4.3       wheel
# boltons                       23.0.0      24.0.0      wheel
# boto3                         1.34.82     1.35.5      wheel
# botocore                      1.34.82     1.35.5      wheel
# Bottleneck                    1.3.7       1.4.0       wheel
# Brotli                        1.0.9       1.1.0       wheel
# cachetools                    5.3.0       5.5.0       wheel
# certifi                       2024.2.2    2024.7.4    wheel
# cffi                          1.15.1      1.17.0      wheel
# chardet                       4.0.0       5.2.0       wheel
# charset-normalizer            2.0.4       3.3.2       wheel
# clarabel                      0.8.1       0.9.0       wheel
# cloudpathlib                  0.16.0      0.18.1      wheel
# cloudpickle                   2.2.1       3.0.0       wheel
# comm                          0.2.1       0.2.2       wheel
# conda-package-handling        2.2.0       2.3.0       wheel
# conda_package_streaming       0.9.0       0.10.0      wheel
# confection                    0.1.4       0.1.5       wheel
# contourpy                     1.2.0       1.2.1       wheel
# cryptography                  41.0.3      43.0.0      wheel
# cvxpy                         1.5.1       1.5.3       wheel
# cycler                        0.11.0      0.12.1      wheel
# Cython                        3.0.10      3.0.11      wheel
# cytoolz                       0.12.2      0.12.3      wheel
# daal4py                       2023.1.1    2024.6.0    wheel
# dash                          2.17.0      2.17.1      wheel
# dask                          2022.2.1    2024.8.0    wheel
# databricks-cli                0.17.4      0.18.0      wheel
# datashader                    0.16.0      0.16.3      wheel
# debugpy                       1.6.7       1.8.5       wheel
# decorator                     4.4.2       5.1.1       wheel
# diff-match-patch              20200713    20230430    wheel
# dill                          0.3.7       0.3.8       wheel
# distributed                   2022.2.1    2024.8.0    wheel
# dnspython                     2.3.0       2.6.1       wheel
# docker                        6.0.1       7.1.0       wheel
# docstring-to-markdown         0.11        0.15        wheel
# docutils                      0.18.1      0.21.2      wheel
# ecos                          2.0.13      2.0.14      wheel
# exceptiongroup                1.1.3       1.2.2       wheel
# executing                     0.8.3       2.0.1       wheel
# falcon                        3.1.1       3.1.3       wheel
# fastapi                       0.104.1     0.112.1     wheel
# fastjsonschema                2.16.2      2.20.0      wheel
# ffmpy                         0.3.1       0.4.0       wheel
# filelock                      3.13.1      3.15.4      wheel
# flake8                        7.0.0       7.1.1       wheel
# Flask                         2.2.5       3.0.3       wheel
# fonttools                     4.51.0      4.53.1      wheel
# fsspec                        2024.3.1    2024.6.1    wheel
# future                        0.18.3      1.0.0       wheel
# FuzzyTM                       2.0.5       2.0.9       wheel
# gast                          0.4.0       0.6.0       wheel
# gensim                        4.3.0       4.3.3       wheel
# geopandas                     0.14.4      1.0.1       wheel
# gitdb                         4.0.10      4.0.11      wheel
# GitPython                     3.1.29      3.1.43      wheel
# gmpy2                         2.1.2       2.2.1       wheel
# google-api-core               2.11.0      2.19.1      wheel
# google-auth                   2.16.1      2.34.0      wheel
# google-auth-oauthlib          0.4.6       1.2.1       wheel
# google-cloud-speech           2.17.3      2.27.0      wheel
# googleapis-common-protos      1.58.0      1.63.2      wheel
# gradio                        4.0.2       4.42.0      wheel
# gradio_client                 0.7.0       1.3.0       wheel
# greenlet                      3.0.1       3.0.3       wheel
# grpcio                        1.51.3      1.66.0      wheel
# grpcio-status                 1.51.3      1.66.0      wheel
# gunicorn                      20.1.0      23.0.0      wheel
# holoviews                     1.18.3      1.19.1      wheel
# httpcore                      1.0.1       1.0.5       wheel
# httpx                         0.25.1      0.27.0      wheel
# huggingface-hub               0.20.3      0.24.6      wheel
# hvplot                        0.9.2       0.10.0      wheel
# hydra-core                    1.0.7       1.3.2       wheel
# idna                          3.7         3.8         wheel
# imagecodecs                   2023.1.23   2024.6.1    wheel
# imageio                       2.33.1      2.35.1      wheel
# imageio-ffmpeg                0.4.8       0.5.1       wheel
# importlib-metadata            7.0.1       8.4.0       wheel
# importlib-resources           6.1.1       6.4.4       wheel
# incremental                   22.10.0     24.7.2      wheel
# iniconfig                     1.1.1       2.0.0       wheel
# intake                        0.6.8       2.0.6       wheel
# ipykernel                     6.25.0      6.29.5      wheel
# ipython                       8.15.0      8.18.1      wheel
# ipywidgets                    8.1.2       8.1.5       wheel
# isort                         5.9.3       5.13.2      wheel
# itemadapter                   0.3.0       0.9.0       wheel
# itemloaders                   1.1.0       1.3.1       wheel
# itsdangerous                  2.0.1       2.2.0       wheel
# jaraco.classes                3.2.1       3.4.0       wheel
# jedi                          0.18.1      0.19.1      wheel
# jeepney                       0.7.1       0.8.0       wheel
# jellyfish                     1.0.1       1.1.0       wheel
# Jinja2                        3.1.3       3.1.4       wheel
# joblib                        1.4.0       1.4.2       wheel
# Js2Py                         0.71        0.74        wheel
# json5                         0.9.6       0.9.25      wheel
# jsonpointer                   2.1         3.0.0       wheel
# jsonschema                    4.19.2      4.23.0      wheel
# jsonschema-specifications     2023.7.1    2023.12.1   wheel
# jupyter_client                8.6.0       8.6.2       wheel
# jupyter_core                  5.5.0       5.7.2       wheel
# jupyter-events                0.8.0       0.10.0      wheel
# jupyter-lsp                   2.2.0       2.2.5       wheel
# jupyter_server                2.10.0      2.14.2      wheel
# jupyter_server_terminals      0.4.4       0.5.3       wheel
# jupyterlab                    4.0.11      4.2.4       wheel
# jupyterlab-pygments           0.1.2       0.3.0       wheel
# jupyterlab_server             2.25.1      2.27.3      wheel
# jupyterlab-widgets            3.0.10      3.0.13      wheel
# kaggle                        1.6.12      1.6.17      sdist
# keras                         3.3.3       3.5.0       wheel
# keyring                       24.3.1      25.3.0      wheel
# kiwisolver                    1.4.4       1.4.5       wheel
# langcodes                     3.3.0       3.4.0       wheel
# lazy_loader                   0.3         0.4         wheel
# Levenshtein                   0.21.1      0.25.1      wheel
# libarchive-c                  2.9         5.1         wheel
# libclang                      14.0.6      18.1.1      wheel
# lightning-utilities           0.10.1      0.11.6      wheel
# linkify-it-py                 2.0.0       2.0.3       wheel
# llvmlite                      0.42.0      0.43.0      wheel
# lmdb                          1.4.1       1.5.1       wheel
# lxml                          4.9.3       5.3.0       wheel
# Mako                          1.2.4       1.3.5       wheel
# Markdown                      3.4.1       3.7         wheel
# markdown-it-py                2.2.0       3.0.0       wheel
# MarkupSafe                    2.1.3       2.1.5       wheel
# matplotlib                    3.8.4       3.9.2       wheel
# matplotlib-inline             0.1.6       0.1.7       wheel
# mdit-py-plugins               0.3.0       0.4.1       wheel
# mdurl                         0.1.0       0.1.2       wheel
# mistune                       2.0.4       3.0.2       wheel
# mizani                        0.9.2       0.11.4      wheel
# mkl-service                   2.4.0       2.4.1       wheel
# ml-dtypes                     0.3.2       0.4.0       wheel
# mlflow                        2.0.1       2.15.1      wheel
# more-itertools                10.1.0      10.4.0      wheel
# msgpack                       1.0.3       1.0.8       wheel
# multidict                     6.0.4       6.0.5       wheel
# multipledispatch              0.6.0       1.0.0       wheel
# mysql-connector-python        8.4.0       9.0.0       wheel
# nbclient                      0.8.0       0.10.0      wheel
# networkx                      3.1         3.2.1       wheel
# nltk                          3.8.1       3.9.1       wheel
# notebook                      7.0.8       7.2.1       wheel
# notebook_shim                 0.2.3       0.2.4       wheel
# numba                         0.59.1      0.60.0      wheel
# numexpr                       2.8.7       2.10.1      wheel
# numpy                         1.26.4      2.0.1       wheel
# numpydoc                      1.5.0       1.8.0       wheel
# nvidia-cublas-cu11            11.10.3.66  11.11.3.6   wheel
# nvidia-cuda-nvrtc-cu11        11.7.99     11.8.89     wheel
# nvidia-cuda-runtime-cu11      11.7.99     11.8.89     wheel
# nvidia-cudnn-cu11             8.5.0.96    9.3.0.75    wheel
# oauthlib                      3.2.0       3.2.2       wheel
# olefile                       0.46        0.47        wheel
# openai                        1.2.0       1.42.0      wheel
# opencv-python                 4.6.0.66    4.10.0.84   wheel
# opencv-python-headless        4.8.1.78    4.10.0.84   wheel
# openpyxl                      3.1.2       3.1.5       wheel
# optree                        0.11.0      0.12.1      wheel
# orion                         0.2.6       0.2.7       sdist
# orjson                        3.9.10      3.10.7      wheel
# osqp                          0.6.5       0.6.7.post1 wheel
# overrides                     7.4.0       7.7.0       wheel
# packaging                     23.2        24.1        wheel
# pandas                        2.2.1       2.2.2       wheel
# pandocfilters                 1.5.0       1.5.1       wheel
# panel                         1.4.2       1.4.5       wheel
# param                         2.1.0       2.1.1       wheel
# parsel                        1.8.1       1.9.1       wheel
# parso                         0.8.3       0.8.4       wheel
# partd                         1.4.1       1.4.2       wheel
# pathspec                      0.10.3      0.12.1      wheel
# patsy                         0.5.3       0.5.6       wheel
# pdfminer.six                  20231228    20240706    wheel
# peewee                        3.17.5      3.17.6      sdist
# pexpect                       4.8.0       4.9.0       wheel
# pgmpy                         0.1.24      0.1.26      wheel
# pillow                        10.3.0      10.4.0      wheel
# pip                           23.3.1      24.2        wheel
# pkginfo                       1.9.6       1.11.1      wheel
# platformdirs                  3.10.0      4.2.2       wheel
# plotly                        5.19.0      5.23.0      wheel
# plotnine                      0.12.2      0.13.6      wheel
# pluggy                        1.0.0       1.5.0       wheel
# pomegranate                   1.0.3       1.1.0       wheel
# pooch                         1.8.1       1.8.2       wheel
# portalocker                   2.8.2       2.10.1      wheel
# prometheus-client             0.14.1      0.20.0      wheel
# prompt-toolkit                3.0.43      3.0.47      wheel
# Protego                       0.1.16      0.3.1       wheel
# proto-plus                    1.22.2      1.24.0      wheel
# protobuf                      4.25.3      5.27.3      wheel
# psutil                        5.9.0       6.0.0       wheel
# pure-eval                     0.2.2       0.2.3       wheel
# pyaml                         21.10.1     24.7.0      wheel
# pyarrow                       16.0.0      17.0.0      wheel
# pyasn1                        0.4.8       0.6.0       wheel
# pyasn1-modules                0.2.8       0.4.0       wheel
# PyAudio                       0.2.11      0.2.14      sdist
# pycodestyle                   2.11.1      2.12.1      wheel
# pycparser                     2.21        2.22        wheel
# pycurl                        7.45.2      7.45.3      wheel
# pydantic                      2.4.2       2.8.2       wheel
# pydantic_core                 2.10.1      2.23.0      wheel
# PyDispatcher                  2.0.5       2.0.7       wheel
# pyerfa                        2.0.0       2.0.1.4     wheel
# pyFUME                        0.2.25      0.3.4       wheel
# Pygments                      2.15.1      2.18.0      wheel
# pyinstaller                   6.8.0       6.10.0      wheel
# pyinstaller-hooks-contrib     2024.7      2024.8      wheel
# PyJWT                         2.4.0       2.9.0       wheel
# pylint                        2.16.2      3.2.6       wheel
# pymongo                       4.3.3       4.8.0       wheel
# pynput                        1.7.3       1.7.7       wheel
# pyodbc                        5.0.1       5.1.0       wheel
# pyOpenSSL                     23.2.0      24.2.1      wheel
# pyparsing                     3.0.9       3.1.2       wheel
# pyperclip                     1.8.2       1.9.0       sdist
# PyQt5                         5.15.10     5.15.11     wheel
# PyQt5-sip                     12.13.0     12.15.0     wheel
# PyQtWebEngine                 5.15.6      5.15.7      wheel
# pyreadstat                    1.2.6       1.2.7       wheel
# PyScreeze                     0.1.29      1.0.1       sdist
# pytest                        7.4.0       8.3.2       wheel
# python-bidi                   0.4.2       0.6.0       wheel
# python-dateutil               2.8.2       2.9.0.post0 wheel
# python-Levenshtein            0.21.1      0.25.1      wheel
# python-lsp-server             1.10.0      1.11.0      wheel
# python-multipart              0.0.6       0.0.9       wheel
# python-slugify                5.0.2       8.0.4       wheel
# python-snappy                 0.6.1       0.7.2       wheel
# pytoolconfig                  1.2.6       1.3.1       wheel
# pytorch-lightning             2.0.9.post0 2.4.0       wheel
# pyttsx3                       2.90        2.91        wheel
# pytweening                    1.0.7       1.2.0       sdist
# pyviz_comms                   3.0.2       3.0.3       wheel
# pywavelets                    1.5.0       1.6.0       wheel
# pyxdg                         0.27        0.28        wheel
# PyYAML                        6.0.1       6.0.2       wheel
# pyzmq                         25.1.2      26.2.0      wheel
# qdldl                         0.1.7.post2 0.1.7.post4 wheel
# qstylizer                     0.2.2       0.2.3       wheel
# QtAwesome                     1.2.2       1.3.1       wheel
# qtconsole                     5.5.1       5.5.2       wheel
# queuelib                      1.6.2       1.7.0       wheel
# rapidfuzz                     3.2.0       3.9.6       wheel
# referencing                   0.30.2      0.35.1      wheel
# regex                         2023.10.3   2024.7.24   wheel
# reportlab                     4.1.0       4.2.2       wheel
# requests                      2.31.0      2.32.3      wheel
# requests-file                 1.5.1       2.1.0       wheel
# requests-oauthlib             1.3.1       2.0.0       wheel
# resampy                       0.4.0       0.4.3       wheel
# rich                          13.3.5      13.7.1      wheel
# rope                          1.12.0      1.13.0      wheel
# rpds-py                       0.10.6      0.20.0      wheel
# Rtree                         1.0.1       1.3.0       wheel
# ruamel.yaml                   0.17.21     0.18.6      wheel
# ruamel.yaml.clib              0.2.6       0.2.8       wheel
# s3transfer                    0.10.1      0.10.2      wheel
# sacrebleu                     2.4.0       2.4.3       wheel
# safetensors                   0.4.2       0.4.4       wheel
# scikit-image                  0.22.0      0.24.0      wheel
# scikit-learn                  1.5.0       1.5.1       wheel
# scikit-optimize               0.9.0       0.10.2      wheel
# scipy                         1.11.4      1.13.1      wheel
# Scrapy                        2.11.1      2.11.2      wheel
# scs                           3.2.4.post1 3.2.6       wheel
# seaborn                       0.12.2      0.13.2      wheel
# SecretStorage                 3.3.1       3.3.3       wheel
# Send2Trash                    1.8.2       1.8.3       wheel
# service-identity              18.1.0      24.1.0      wheel
# setuptools                    68.2.2      73.0.1      wheel
# shap                          0.41.0      0.46.0      wheel
# shapely                       2.0.2       2.0.6       wheel
# simpful                       2.11.1      2.12.0      wheel
# sip                           6.7.12      6.8.6       wheel
# siuba                         0.4.2       0.4.4       wheel
# sklearn                       0.0.post1   0.0.post12  sdist
# slicer                        0.0.7       0.0.8       wheel
# smart-open                    5.2.1       7.0.4       wheel
# smmap                         5.0.0       5.0.1       wheel
# sniffio                       1.3.0       1.3.1       wheel
# soundata                      0.1.2       1.0.1       wheel
# sounddevice                   0.4.5       0.5.0       wheel
# soupsieve                     2.5         2.6         wheel
# soxr                          0.3.7       0.4.0       wheel
# spacy                         3.7.2       3.7.6       wheel
# SpeechRecognition             3.9.0       3.10.4      wheel
# Sphinx                        5.0.2       7.4.7       wheel
# sphinxcontrib-applehelp       1.0.2       2.0.0       wheel
# sphinxcontrib-devhelp         1.0.2       2.0.0       wheel
# sphinxcontrib-htmlhelp        2.0.0       2.1.0       wheel
# sphinxcontrib-qthelp          1.0.3       2.0.0       wheel
# sphinxcontrib-serializinghtml 1.1.5       2.0.0       wheel
# spyder                        5.5.1       5.5.5       wheel
# spyder-kernels                2.5.0       2.5.2       wheel
# SQLAlchemy                    2.0.25      2.0.32      wheel
# sqlparse                      0.4.3       0.5.1       wheel
# stack-data                    0.2.0       0.6.3       wheel
# starlette                     0.27.0      0.38.2      wheel
# statsmodels                   0.14.0      0.14.2      wheel
# sympy                         1.12        1.13.2      wheel
# TBB                           0.2         2021.13.1   wheel
# tblib                         1.7.0       3.0.0       wheel
# tenacity                      8.2.2       9.0.0       wheel
# tensorboard                   2.16.2      2.17.1      wheel
# tensorflow                    2.16.1      2.17.0      wheel
# tensorflow-estimator          2.9.0       2.15.0      wheel
# tensorflow-io-gcs-filesystem  0.26.0      0.37.1      wheel
# termcolor                     1.1.0       2.4.0       wheel
# terminado                     0.17.1      0.18.1      wheel
# textdistance                  4.2.1       4.6.3       wheel
# tgt                           1.4.4       1.5         wheel
# thinc                         8.2.2       9.0.0       wheel
# tifffile                      2023.4.12   2024.8.10   wheel
# tinycss2                      1.2.1       1.3.0       wheel
# tldextract                    3.2.0       5.1.2       wheel
# tokenizers                    0.15.1      0.20.0      wheel
# tomlkit                       0.11.1      0.13.2      wheel
# toolz                         0.12.0      0.12.1      wheel
# torch                         1.11.0      2.4.0       wheel
# torchaudio                    0.11.0      2.4.0       wheel
# torchmetrics                  1.3.0.post0 1.4.1       wheel
# torchvision                   0.14.1      0.19.0      wheel
# tornado                       6.3.3       6.4.1       wheel
# tqdm                          4.66.2      4.66.5      wheel
# traitlets                     5.7.1       5.14.3      wheel
# transformers                  4.37.2      4.44.2      wheel
# Twisted                       23.10.0     24.7.0      wheel
# typer                         0.9.0       0.12.4      wheel
# typing_extensions             4.8.0       4.12.2      wheel
# tzdata                        2023.3      2024.1      wheel
# tzlocal                       4.2         5.2         wheel
# uc-micro-py                   1.0.1       1.0.3       wheel
# ujson                         5.4.0       5.10.0      wheel
# Unidecode                     1.2.0       1.3.8       wheel
# urllib3                       1.26.18     2.2.2       wheel
# uvicorn                       0.23.2      0.30.6      wheel
# w3lib                         2.1.2       2.2.1       wheel
# wasabi                        1.1.2       1.1.3       wheel
# watchdog                      2.1.6       4.0.2       wheel
# wcwidth                       0.2.5       0.2.13      wheel
# weasel                        0.3.4       0.4.1       wheel
# websocket-client              0.58.0      1.8.0       wheel
# websockets                    10.4        13.0        wheel
# Werkzeug                      2.2.3       3.0.4       wheel
# whatthepatch                  1.0.2       1.0.6       wheel
# wheel                         0.43.0      0.44.0      wheel
# widgetsnbextension            4.0.10      4.0.13      wheel
# wordcloud                     1.9.2       1.9.3       wheel
# wrapt                         1.11.2      1.16.0      wheel
# wurlitzer                     3.0.2       3.1.1       wheel
# xarray                        2023.6.0    2024.7.0    wheel
# XlsxWriter                    3.1.1       3.2.0       wheel
# xyzservices                   2022.9.0    2024.6.0    wheel
# yfinance                      0.2.40      0.2.42      wheel
# zipp                          3.17.0      3.20.0      wheel
# zope.interface                5.4.0       7.0.1       wheel
# zstandard                     0.22.0      0.23.0      wheel

# %% [markdown]
# Este comando mostrará una lista de todos los paquetes instalados que tienen versiones más nuevas disponibles.

# %% [markdown]
# ## 2.6. Actualizar todos los paquetes obsoletos en Windows
#
# Para visualizar los paquetes obsoletos en un sistema Windows, puedes ejecutar el siguiente comando:

# %%
# !pip list --outdated

# %% [markdown]
# ## 2.7. Crear un archivo requirements.txt de todos los paquetes en el sistema
#
# Para crear un archivo requirements.txt que contenga todos los paquetes instalados en tu sistema, puedes ejecutar el siguiente comando:

# %%
# !pip freeze > requirements.txt

# %% [markdown]
# Para instalar un archivo requirements.txt que contiene una lista de dependencias de Python, simplemente puedes usar el siguiente comando:

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## 2.8. Instalar con wheel (Paquetes externos)
#
# Para instalar un paquete desde un archivo de rueda (wheel), puedes utilizar el siguiente comando:

# %%
# !pip install nombre_del_archivo.whl

# %% [markdown]
# ## Tema 3: Módulo, Paquetes y Namespaces en Python
#
# En Python, los módulos, paquetes y namespaces son componentes esenciales para organizar y estructurar programas de manera efectiva. A continuación, exploraremos cada uno de ellos en detalle:
# Módulos en Python:
#
# ### Módulos
# Los módulos son archivos de Python que encapsulan código reusable. Pueden contener variables, funciones y clases que se pueden utilizar en otros programas. Para emplear un módulo en un programa, es necesario importarlo primero.

# %%
# Usando el módulo en otro archivo
import mimodulo

mimodulo.saludar("Juan")
# Out:
# ¡Hola, Juan!

# %% [markdown]
# ### Paquetes en Python:
#
# Los paquetes son directorios que agrupan módulos relacionados. Para ser reconocidos como paquetes, deben contener un archivo especial llamado __init__.py. Esto ayuda a organizar y estructurar el código de manera más jerárquica.

# %% [markdown]
# mi_paquete/
# │   __init__.py
# │   modulo1.py
# │   modulo2.py

# %% [markdown]
# ## Namespaces en Python:
#
# Un namespace es un espacio que contiene nombres de variables, funciones, clases, etc. Ayuda a evitar conflictos de nombres y organizar el código de manera más clara.
#
# Ejemplo de namespaces en Python:

# %%
class MiClase:
    def __init__(self, nombre):  # Agregamos el parámetro nombre al constructor
        self.nombre = nombre     # Nuevo atributo de la clase
        self.valor = 5           # Atributo existente


# Creamos un objeto de la clase MiClase con el nombre "My_var"
objeto = MiClase("My_var")

# Accedemos a los atributos del objeto e imprimimos sus valores
print(objeto.nombre)
print(objeto.valor)
# Out:
# My_var
# 5
